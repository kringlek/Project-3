# %%
import pandas as pd
import numpy as np
import json

# %%
# read in cleaned hurricane data
hurricane_data = pd.read_json("../static/js/test.json")

# %%
hurricane_data.head()
# Out:
#       Name                     Areas affected      Month  Day  Year  \
# 0    Janet   Lesser Antilles, Central America  September   27  1955
# 1     Inez  Greater Antilles, Florida, Mexico  September   28  1966
# 2     Inez  Greater Antilles, Florida, Mexico  September   28  1966
# 3     Inez  Greater Antilles, Florida, Mexico  September   28  1966
# 4  Camille     Cuba, United States Gulf Coast     August   16  1969
#
#    Wind Speed (mph) Pressure (hPa)  Damages ($)  Deaths   lat  long  category  \
# 0               175            914     65800000    1023  17.3 -83.0         4
# 1               165            927    229000000     756  16.3 -63.0         3
# 2               165            927    229000000     756  16.5 -64.4         4
# 3               165            927    229000000     756  17.0 -67.2         5
# 4               175            900   1420000000     259  24.3 -86.6         5
#
#       Name_year
# 0    Janet 1955
# 1     Inez 1966
# 2     Inez 1966
# 3     Inez 1966
# 4  Camille 1969

# %%
# since no column names on csv, need to name them
col_names = ["name", "date", "time_UTC", "record_identifier", "status", "latitude", "longitude", "max_wind_knots", "min_pressure_millibars", 
             "34kt_wind_radii_NE", "34kt_wind_radii_SE", "34kt_wind_radii_SW", "34kt_wind_radii_NW",
            "50kt_wind_radii_NE", "50kt_wind_radii_SE", "50kt_wind_radii_SW", "50kt_wind_radii_NW",
            "64kt_wind_radii_NE", "64kt_wind_radii_SE", "64kt_wind_radii_SW", "64kt_wind_radii_NW", "radius_max_wind"]

# read in csv with column names above
noaa_data = pd.read_csv("../Data/NOAA_reformatted.csv", header=None, names=col_names)

# %%
noaa_data
# Out:
#                       name      date             time_UTC record_identifier  \
# 0                      NaN  AL011851              UNNAMED                14
# 1                  UNNAMED  18510625                    0
# 2                  UNNAMED  18510625                  600
# 3                  UNNAMED  18510625                 1200
# 4                  UNNAMED  18510625                 1800
# ...                    ...       ...                  ...               ...
# 55432                WANDA  20211107                    0
# 55433                WANDA  20211107                  600
# 55434                WANDA  20211107                 1200
# 55435                WANDA  20211107                 1800
# 55436                WANDA  20211108                    0
#
#       status latitude longitude  max_wind_knots  min_pressure_millibars  \
# 0        NaN      NaN       NaN             NaN                     NaN
# 1         HU    28.0N     94.8W            80.0                  -999.0
# 2         HU    28.0N     95.4W            80.0                  -999.0
# 3         HU    28.0N     96.0W            80.0                  -999.0
# 4         HU    28.1N     96.5W            80.0                  -999.0
# ...      ...      ...       ...             ...                     ...
# 55432     TS    37.4N     37.4W            35.0                  1003.0
# 55433     TS    38.1N     36.4W            35.0                  1004.0
# 55434     LO    39.2N     34.9W            35.0                  1006.0
# 55435     LO    40.9N     32.8W            40.0                  1006.0
# 55436     LO    43.2N     29.7W            40.0                  1006.0
#
#        34kt_wind_radii_NE  ...  34kt_wind_radii_NW  50kt_wind_radii_NE  \
# 0                     NaN  ...                 NaN                 NaN
# 1                  -999.0  ...              -999.0              -999.0
# 2                  -999.0  ...              -999.0              -999.0
# 3                  -999.0  ...              -999.0              -999.0
# 4                  -999.0  ...              -999.0              -999.0
# ...                   ...  ...                 ...                 ...
# 55432                 0.0  ...                 0.0                 0.0
# 55433                 0.0  ...                 0.0                 0.0
# 55434                 0.0  ...                 0.0                 0.0
# 55435                 0.0  ...                 0.0                 0.0
# 55436                30.0  ...                 0.0                 0.0
#
#        50kt_wind_radii_SE  50kt_wind_radii_SW  50kt_wind_radii_NW  \
# 0                     NaN                 NaN                 NaN
# 1                  -999.0              -999.0              -999.0
# 2                  -999.0              -999.0              -999.0
# 3                  -999.0              -999.0              -999.0
# 4                  -999.0              -999.0              -999.0
# ...                   ...                 ...                 ...
# 55432                 0.0                 0.0                 0.0
# 55433                 0.0                 0.0                 0.0
# 55434                 0.0                 0.0                 0.0
# 55435                 0.0                 0.0                 0.0
# 55436                 0.0                 0.0                 0.0
#
#        64kt_wind_radii_NE  64kt_wind_radii_SE  64kt_wind_radii_SW  \
# 0                     NaN                 NaN                 NaN
# 1                  -999.0              -999.0              -999.0
# 2                  -999.0              -999.0              -999.0
# 3                  -999.0              -999.0              -999.0
# 4                  -999.0              -999.0              -999.0
# ...                   ...                 ...                 ...
# 55432                 0.0                 0.0                 0.0
# 55433                 0.0                 0.0                 0.0
# 55434                 0.0                 0.0                 0.0
# 55435                 0.0                 0.0                 0.0
# 55436                 0.0                 0.0                 0.0
#
#        64kt_wind_radii_NW  radius_max_wind
# 0                     NaN              NaN
# 1                  -999.0           -999.0
# 2                  -999.0           -999.0
# 3                  -999.0           -999.0
# 4                  -999.0           -999.0
# ...                   ...              ...
# 55432                 0.0             40.0
# 55433                 0.0             45.0
# 55434                 0.0             50.0
# 55435                 0.0             50.0
# 55436                 0.0             40.0
#
# [55437 rows x 22 columns]

# %%
# get rid of unnecessary columns
wanted_cols = ["name", "date", "time_UTC", "latitude", "longitude", "status", "max_wind_knots"]
noaa_df = noaa_data[wanted_cols].copy()

# drop rows with NaN values (the row with the name of the hurricane has many of these)
noaa_df.dropna(inplace=True)

# make names all lowercase except for first letter
noaa_df["name"] = noaa_df["name"].str.lower()
noaa_df["name"] = noaa_df["name"].str.title()

# strip whitespace from beginning of names
noaa_df["name"] = noaa_df["name"].str.lstrip()

# %%
noaa_df
# Out:
#           name      date time_UTC latitude longitude status  max_wind_knots
# 1      Unnamed  18510625        0    28.0N     94.8W     HU            80.0
# 2      Unnamed  18510625      600    28.0N     95.4W     HU            80.0
# 3      Unnamed  18510625     1200    28.0N     96.0W     HU            80.0
# 4      Unnamed  18510625     1800    28.1N     96.5W     HU            80.0
# 5      Unnamed  18510625     2100    28.2N     96.8W     HU            80.0
# ...        ...       ...      ...      ...       ...    ...             ...
# 55432    Wanda  20211107        0    37.4N     37.4W     TS            35.0
# 55433    Wanda  20211107      600    38.1N     36.4W     TS            35.0
# 55434    Wanda  20211107     1200    39.2N     34.9W     LO            35.0
# 55435    Wanda  20211107     1800    40.9N     32.8W     LO            40.0
# 55436    Wanda  20211108        0    43.2N     29.7W     LO            40.0
#
# [53501 rows x 7 columns]

# %%
# split up year, month and day
noaa_df["year"] = noaa_df["date"].str.slice(0,4)
noaa_df["month"] = noaa_df["date"].str.slice(4,6)
noaa_df["day"] = noaa_df["date"].str.slice(start=6)

noaa_df
# Out:
#           name      date time_UTC latitude longitude status  max_wind_knots  \
# 1      Unnamed  18510625        0    28.0N     94.8W     HU            80.0
# 2      Unnamed  18510625      600    28.0N     95.4W     HU            80.0
# 3      Unnamed  18510625     1200    28.0N     96.0W     HU            80.0
# 4      Unnamed  18510625     1800    28.1N     96.5W     HU            80.0
# 5      Unnamed  18510625     2100    28.2N     96.8W     HU            80.0
# ...        ...       ...      ...      ...       ...    ...             ...
# 55432    Wanda  20211107        0    37.4N     37.4W     TS            35.0
# 55433    Wanda  20211107      600    38.1N     36.4W     TS            35.0
# 55434    Wanda  20211107     1200    39.2N     34.9W     LO            35.0
# 55435    Wanda  20211107     1800    40.9N     32.8W     LO            40.0
# 55436    Wanda  20211108        0    43.2N     29.7W     LO            40.0
#
#        year month day
# 1      1851    06  25
# 2      1851    06  25
# 3      1851    06  25
# 4      1851    06  25
# 5      1851    06  25
# ...     ...   ...  ..
# 55432  2021    11  07
# 55433  2021    11  07
# 55434  2021    11  07
# 55435  2021    11  07
# 55436  2021    11  08
#
# [53501 rows x 10 columns]

# %%
# get rid of whitespace
noaa_df["latitude"] = noaa_df["latitude"].str.lstrip()
noaa_df["longitude"] = noaa_df["longitude"].str.lstrip()

# split up lat and long from direction
noaa_df["lat_coord"] = noaa_df["latitude"].str.slice(stop=-1)
noaa_df["lat_dir"] = noaa_df["latitude"].str.slice(start=-1)
noaa_df["long_coord"] = noaa_df["longitude"].str.slice(stop=-1)
noaa_df["long_dir"] = noaa_df["longitude"].str.slice(start=-1)

# make the coordinates floats
noaa_df["lat_coord"] = noaa_df["lat_coord"].astype(float)
noaa_df["long_coord"] = noaa_df["long_coord"].astype(float)

noaa_df
# Out:
#           name      date time_UTC latitude longitude status  max_wind_knots  \
# 1      Unnamed  18510625        0    28.0N     94.8W     HU            80.0
# 2      Unnamed  18510625      600    28.0N     95.4W     HU            80.0
# 3      Unnamed  18510625     1200    28.0N     96.0W     HU            80.0
# 4      Unnamed  18510625     1800    28.1N     96.5W     HU            80.0
# 5      Unnamed  18510625     2100    28.2N     96.8W     HU            80.0
# ...        ...       ...      ...      ...       ...    ...             ...
# 55432    Wanda  20211107        0    37.4N     37.4W     TS            35.0
# 55433    Wanda  20211107      600    38.1N     36.4W     TS            35.0
# 55434    Wanda  20211107     1200    39.2N     34.9W     LO            35.0
# 55435    Wanda  20211107     1800    40.9N     32.8W     LO            40.0
# 55436    Wanda  20211108        0    43.2N     29.7W     LO            40.0
#
#        year month day  lat_coord lat_dir  long_coord long_dir
# 1      1851    06  25       28.0       N        94.8        W
# 2      1851    06  25       28.0       N        95.4        W
# 3      1851    06  25       28.0       N        96.0        W
# 4      1851    06  25       28.1       N        96.5        W
# 5      1851    06  25       28.2       N        96.8        W
# ...     ...   ...  ..        ...     ...         ...      ...
# 55432  2021    11  07       37.4       N        37.4        W
# 55433  2021    11  07       38.1       N        36.4        W
# 55434  2021    11  07       39.2       N        34.9        W
# 55435  2021    11  07       40.9       N        32.8        W
# 55436  2021    11  08       43.2       N        29.7        W
#
# [53501 rows x 14 columns]

# %%
# create an id column in noaa data frame so we can compare
noaa_df["id"] = noaa_df["name"] + " " + noaa_df["year"].astype(str)

# %%
hurricane_data.head()
# Out:
#       Name                     Areas affected      Month  Day  Year  \
# 0    Janet   Lesser Antilles, Central America  September   27  1955
# 1     Inez  Greater Antilles, Florida, Mexico  September   28  1966
# 2     Inez  Greater Antilles, Florida, Mexico  September   28  1966
# 3     Inez  Greater Antilles, Florida, Mexico  September   28  1966
# 4  Camille     Cuba, United States Gulf Coast     August   16  1969
#
#    Wind Speed (mph) Pressure (hPa)  Damages ($)  Deaths   lat  long  category  \
# 0               175            914     65800000    1023  17.3 -83.0         4
# 1               165            927    229000000     756  16.3 -63.0         3
# 2               165            927    229000000     756  16.5 -64.4         4
# 3               165            927    229000000     756  17.0 -67.2         5
# 4               175            900   1420000000     259  24.3 -86.6         5
#
#       Name_year
# 0    Janet 1955
# 1     Inez 1966
# 2     Inez 1966
# 3     Inez 1966
# 4  Camille 1969

# %%
noaa_df.head()
# Out:
#       name      date time_UTC latitude longitude status  max_wind_knots  year  \
# 1  Unnamed  18510625        0    28.0N     94.8W     HU            80.0  1851
# 2  Unnamed  18510625      600    28.0N     95.4W     HU            80.0  1851
# 3  Unnamed  18510625     1200    28.0N     96.0W     HU            80.0  1851
# 4  Unnamed  18510625     1800    28.1N     96.5W     HU            80.0  1851
# 5  Unnamed  18510625     2100    28.2N     96.8W     HU            80.0  1851
#
#   month day  lat_coord lat_dir  long_coord long_dir            id
# 1    06  25       28.0       N        94.8        W  Unnamed 1851
# 2    06  25       28.0       N        95.4        W  Unnamed 1851
# 3    06  25       28.0       N        96.0        W  Unnamed 1851
# 4    06  25       28.1       N        96.5        W  Unnamed 1851
# 5    06  25       28.2       N        96.8        W  Unnamed 1851

# %%
# create list of hurricane ids from cleaned dataset to compare with noaa dataset
hurr_names = hurricane_data["Name_year"].unique().tolist()

# %%
# get only the rows with the same hurricanes as in our cleaned dataset
noaa_match_names = noaa_df.loc[noaa_df["id"].isin(hurr_names)]
noaa_match_names = noaa_match_names.reset_index(drop=True)
noaa_match_names
# Out:
#        name      date time_UTC latitude longitude status  max_wind_knots  \
# 0     Janet  19550921     1200    13.2N     52.6W     TS            40.0
# 1     Janet  19550921     1800    13.2N     54.3W     TS            50.0
# 2     Janet  19550922        0    13.2N     56.0W     TS            60.0
# 3     Janet  19550922      600    13.1N     57.5W     HU            70.0
# 4     Janet  19550922     1200    13.0N     58.9W     HU            80.0
# ...     ...       ...      ...      ...       ...    ...             ...
# 2472  Larry  20210911        0    45.1N     56.6W     HU            70.0
# 2473  Larry  20210911      330    47.3N     54.6W     HU            70.0
# 2474  Larry  20210911      600    48.8N     53.3W     HU            65.0
# 2475  Larry  20210911     1200    52.5N     49.7W     EX            60.0
# 2476  Larry  20210911     1800    55.3N     46.8W     EX            55.0
#
#       year month day  lat_coord lat_dir  long_coord long_dir          id
# 0     1955    09  21       13.2       N        52.6        W  Janet 1955
# 1     1955    09  21       13.2       N        54.3        W  Janet 1955
# 2     1955    09  22       13.2       N        56.0        W  Janet 1955
# 3     1955    09  22       13.1       N        57.5        W  Janet 1955
# 4     1955    09  22       13.0       N        58.9        W  Janet 1955
# ...    ...   ...  ..        ...     ...         ...      ...         ...
# 2472  2021    09  11       45.1       N        56.6        W  Larry 2021
# 2473  2021    09  11       47.3       N        54.6        W  Larry 2021
# 2474  2021    09  11       48.8       N        53.3        W  Larry 2021
# 2475  2021    09  11       52.5       N        49.7        W  Larry 2021
# 2476  2021    09  11       55.3       N        46.8        W  Larry 2021
#
# [2477 rows x 15 columns]

# %%
# clean up the dataframe for export

# convert coordinates to pos and neg based on direction
noaa_match_names["lat_coord"] = np.where(noaa_match_names["lat_dir"] == "S", noaa_match_names["lat_coord"]*-1, noaa_match_names["lat_coord"])
noaa_match_names["long_coord"] = np.where(noaa_match_names["long_dir"] == "W", noaa_match_names["long_coord"]*-1, noaa_match_names["long_coord"])

# %%
noaa_match_names
# Out:
#        name      date time_UTC latitude longitude status  max_wind_knots  \
# 0     Janet  19550921     1200    13.2N     52.6W     TS            40.0
# 1     Janet  19550921     1800    13.2N     54.3W     TS            50.0
# 2     Janet  19550922        0    13.2N     56.0W     TS            60.0
# 3     Janet  19550922      600    13.1N     57.5W     HU            70.0
# 4     Janet  19550922     1200    13.0N     58.9W     HU            80.0
# ...     ...       ...      ...      ...       ...    ...             ...
# 2472  Larry  20210911        0    45.1N     56.6W     HU            70.0
# 2473  Larry  20210911      330    47.3N     54.6W     HU            70.0
# 2474  Larry  20210911      600    48.8N     53.3W     HU            65.0
# 2475  Larry  20210911     1200    52.5N     49.7W     EX            60.0
# 2476  Larry  20210911     1800    55.3N     46.8W     EX            55.0
#
#       year month day  lat_coord lat_dir  long_coord long_dir          id
# 0     1955    09  21       13.2       N       -52.6        W  Janet 1955
# 1     1955    09  21       13.2       N       -54.3        W  Janet 1955
# 2     1955    09  22       13.2       N       -56.0        W  Janet 1955
# 3     1955    09  22       13.1       N       -57.5        W  Janet 1955
# 4     1955    09  22       13.0       N       -58.9        W  Janet 1955
# ...    ...   ...  ..        ...     ...         ...      ...         ...
# 2472  2021    09  11       45.1       N       -56.6        W  Larry 2021
# 2473  2021    09  11       47.3       N       -54.6        W  Larry 2021
# 2474  2021    09  11       48.8       N       -53.3        W  Larry 2021
# 2475  2021    09  11       52.5       N       -49.7        W  Larry 2021
# 2476  2021    09  11       55.3       N       -46.8        W  Larry 2021
#
# [2477 rows x 15 columns]

# %%
# columns to keep for json file
cols_to_keep = ["name", "time_UTC", "year", "month", "day", "lat_coord", "long_coord", "id", "status", "max_wind_knots"]
final_df = noaa_match_names[cols_to_keep].copy()

# reset the index
final_df = final_df.reset_index(drop=True)

# group by id
grouped = final_df.groupby("id")

# get list of hurricane ids
hurricane_ids = final_df["id"].unique().tolist()

# %%
final_dict = {}

for hurricane in hurricane_ids:
    hurricane_name = hurricane.split()[0]
    
    lat_coords = grouped.get_group(hurricane)["lat_coord"].tolist()
    long_coords = grouped.get_group(hurricane)["long_coord"].tolist()
    
    coords = []
    for i in range(len(lat_coords)):
        coords.append([lat_coords[i], long_coords[i]])
        
    hurr_dict = {
        "name": hurricane_name,
        "time_UTC": grouped.get_group(hurricane)["time_UTC"].tolist(),
        "year": grouped.get_group(hurricane)["year"].tolist(),
        "month": grouped.get_group(hurricane)["month"].tolist(),
        "day": grouped.get_group(hurricane)["day"].tolist(),
#         "coords": {"lat": grouped.get_group(hurricane)["lat_coord"].tolist(),
#                 "long": grouped.get_group(hurricane)["long_coord"].tolist()},
        "coords": coords,
        "id": grouped.get_group(hurricane)["id"].tolist(),
        "status": grouped.get_group(hurricane)["status"].tolist(),
        "max_wind_knots": grouped.get_group(hurricane)["max_wind_knots"].to_list()
    }
    final_dict[hurricane] = hurr_dict

# %%
# write our results as a json
with open("../static/js/hurricane_path.json", "w") as outfile:
    json.dump(final_dict, outfile)
