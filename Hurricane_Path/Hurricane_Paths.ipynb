# %%
import pandas as pd

# %%
hurricane_data = pd.read_csv("Data/hurricane_clean_dataset.csv")
hurricane_data
# Out:
#             Name                                     Areas affected  \
# 0     San Felipe  Lesser Antilles, The Bahamas,United States Eas...
# 1       Camaguey  Lesser Antilles, Jamaica, Cayman Islands, Cuba...
# 2    New England         Eastern United States, Southwestern Quebec
# 3          Janet                   Lesser Antilles, Central America
# 4           Inez                  Greater Antilles, Florida, Mexico
# ..           ...                                                ...
# 97      Humberto       Texas, Louisiana, Mississippi, The Carolinas
# 98       Lorenzo                                     Central Mexico
# 99          Noel  The Caribbean, The Bahamas, Florida, Eastern U...
# 100        Hanna  Puerto Rico, Turks and Caicos Islands, The Bah...
# 101         Kyle  Puerto Rico, Hispaniola, Bermuda, New England,...
#
#          Month Day  Year  Wind Speed (mph) Pressure (hPa)  Damages ($)  Deaths
# ...

# %%
noaa_data = pd.read_csv("Data/NOAA.csv")
noaa_data
# Out:
#                                                                                                                   AL011851  \
# 18510625  0000     HU  28.0N   94.8W 80.0 -999.0  -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0    -999.0
#           0600     HU  28.0N   95.4W 80.0 -999.0  -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0    -999.0
#           1200     HU  28.0N   96.0W 80.0 -999.0  -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0    -999.0
#           1800     HU  28.1N   96.5W 80.0 -999.0  -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0    -999.0
#           2100  L  HU  28.2N   96.8W 80.0 -999.0  -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0    -999.0
# ...                                                                                                                    ...
# ...
